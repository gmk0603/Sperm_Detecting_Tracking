# %%
import os
import torch
import torchvision

os.getcwd()
# Out:
# '/home/vmadmin/goqba/mk2/20230822/YOLO20230822'

# %%
HOME = os.getcwd()
print(HOME)
# Out:
# /home/vmadmin/goqba/mk2/20230822/YOLO20230822

# %%
# !pip uninstall ultralytics --yes
# Out:
# WARNING: Skipping ultralytics as it is not installed.

# %% [markdown]
# # ultralytics 버전 확인

# %%
# !pip install ultralytics==1.1.1.1
# Out:
# ERROR: Could not find a version that satisfies the requirement ultralytics==1.1.1.1 (from versions: 0.0.13, 0.0.14, 0.0.15, 0.0.16, 0.0.17, 0.0.18, 0.0.19, 0.0.20, 0.0.21, 0.0.22, 0.0.23, 0.0.24, 0.0.25, 0.0.26, 0.0.27, 0.0.28, 0.0.29, 0.0.30, 0.0.31, 0.0.32, 0.0.33, 0.0.34, 0.0.35, 0.0.36, 0.0.37, 0.0.38, 0.0.39, 0.0.40, 0.0.41, 0.0.42, 0.0.43, 0.0.44, 8.0.0, 8.0.1, 8.0.2, 8.0.3, 8.0.4, 8.0.5, 8.0.6, 8.0.7, 8.0.8, 8.0.9, 8.0.10, 8.0.11, 8.0.12, 8.0.13, 8.0.14, 8.0.15, 8.0.16, 8.0.17, 8.0.18, 8.0.19, 8.0.20, 8.0.21, 8.0.22, 8.0.23, 8.0.24, 8.0.25, 8.0.26, 8.0.27, 8.0.28, 8.0.29, 8.0.30, 8.0.31, 8.0.32, 8.0.33, 8.0.34, 8.0.35, 8.0.36, 8.0.37, 8.0.38, 8.0.39, 8.0.40, 8.0.41, 8.0.42, 8.0.43, 8.0.44, 8.0.45, 8.0.46, 8.0.47, 8.0.48, 8.0.49, 8.0.50, 8.0.51, 8.0.52, 8.0.53, 8.0.54, 8.0.55, 8.0.56, 8.0.57, 8.0.58, 8.0.59, 8.0.60, 8.0.61, 8.0.62, 8.0.63, 8.0.64, 8.0.65, 8.0.66, 8.0.67, 8.0.68, 8.0.69, 8.0.70, 8.0.71, 8.0.72, 8.0.73, 8.0.74, 8.0.75, 8.0.76, 8.0.77, 8.0.78, 8.0.79, 8.0.80, 8.0.
# ...

# %% [markdown]
# # ultralytics install

# %%
# !pip install ultralytics==8.0.143
# Out:
# ...
#   Using cached ultralytics-8.0.143-py3-none-any.whl (604 kB)
# ...

# %%
from IPython import display
display.clear_output()
# !yolo mode=checks
# Out:
# WARNING ⚠️ 'yolo mode=checks' is deprecated. Use 'yolo checks' instead.
# Ultralytics YOLOv8.0.143 🚀 Python-3.7.16 torch-1.13.1 CUDA:0 (Tesla T4, 14966MiB)
# Setup complete ✅ (64 CPUs, 432.9 GB RAM, 164.0/247.9 GB disk)

# %%
# !yolo checks
# Out:
# Ultralytics YOLOv8.0.143 🚀 Python-3.7.16 torch-1.13.1 CUDA:0 (Tesla T4, 14966MiB)
# Setup complete ✅ (64 CPUs, 432.9 GB RAM, 164.0/247.9 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
import torch

# %%
torch.__version__
# Out:
# '1.13.1'

# %%
import torch
import torchvision

print("PyTorch version:", torch.__version__)
print("torchvision version:", torchvision.__version__)
# Out:
# PyTorch version: 1.13.1
# torchvision version: 0.14.1

# %%
# !pip install --upgrade torch torchvision

# %% [markdown]
# ### cuda 캐시 초기화

# %%
import gc
import torch

gc.collect()
torch.cuda.empty_cache()

# %%
# GPU 할당 변경하기
GPU_NUM = 3 # 원하는 GPU 번호 입력
device = torch.device(f'cuda:{GPU_NUM}' if torch.cuda.is_available() else 'cpu')
torch.cuda.set_device(device) # change allocation of current GPU

print ('# Current cuda device: ', torch.cuda.current_device()) # check
# Out:
# # Current cuda device:  3

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"  # Arrange GPU devices starting from 0
os.environ["CUDA_VISIBLE_DEVICES"]= "0,1,2,3"  # Set the GPUs 2 and 3 to use

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print('Device:', device)
print('Current cuda device:', torch.cuda.current_device())
print('Count of using GPUs:', torch.cuda.device_count())
# Out:
# Device: cuda
# Current cuda device: 3
# Count of using GPUs: 4

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={HOME}/datasets/data.yaml epochs=100 imgsz=640,480 batch=32 --device=0,1,2,3
# Out:
# /home/vmadmin/goqba/mk2/20230822/YOLO20230822
# WARNING ⚠️ '--device=0,1,2,3' does not require leading dashes '--', updating to 'device=0,1,2,3'.
# New https://pypi.org/project/ultralytics/8.0.160 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.143 🚀 Python-3.7.16 torch-1.13.1 CUDA:0 (Tesla T4, 14966MiB)
#                                                        CUDA:1 (Tesla T4, 14966MiB)
#                                                        CUDA:2 (Tesla T4, 14966MiB)
#                                                        CUDA:3 (Tesla T4, 14966MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
 # !ls {HOME}/runs/detect/train2/
# Out:
# F1_curve.png			 labels_correlogram.jpg  train_batch26102.jpg
# PR_curve.png			 results.csv		 val_batch0_labels.jpg
# P_curve.png			 results.png		 val_batch0_pred.jpg
# R_curve.png			 train_batch0.jpg	 val_batch1_labels.jpg
# args.yaml			 train_batch1.jpg	 val_batch1_pred.jpg
# confusion_matrix.png		 train_batch2.jpg	 val_batch2_labels.jpg
# confusion_matrix_normalized.png  train_batch26100.jpg	 val_batch2_pred.jpg
# labels.jpg			 train_batch26101.jpg	 weights

# %%
Image(filename=f'{HOME}/runs/detect/train2/confusion_matrix.png', width=1080)

# %%
Image(filename=f'{HOME}/runs/detect/train2/results.png', width=1080)

# %%
Image(filename=f'{HOME}/runs/detect/train2/val_batch0_pred.jpg', width=1600)

# %%
# %cd {HOME}
# !yolo task=detect mode=val model={HOME}/runs/detect/train2/weights/best.pt data={HOME}/datasets/data.yaml --device=0,1,2,3
# Out:
# /home/vmadmin/goqba/mk2/20230822/YOLO20230822
# WARNING ⚠️ '--device=0,1,2,3' does not require leading dashes '--', updating to 'device=0,1,2,3'.
# Ultralytics YOLOv8.0.143 🚀 Python-3.7.16 torch-1.13.1 CUDA:0 (Tesla T4, 14966MiB)
#                                                        CUDA:1 (Tesla T4, 14966MiB)
#                                                        CUDA:2 (Tesla T4, 14966MiB)
#                                                        CUDA:3 (Tesla T4, 14966MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
# val: Scanning /home/vmadmin/goqba/mk2/20230822/YOLO20230822/datasets/valid/label
#                  Class     Images  Instances      Box(P          R      mAP50  mWARNING ⚠️ NMS time limit 1.300s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2323     549754      0.915      0.824        0.9      0.697
# ...

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train25/weights/best.pt conf=0.25 source={HOME}/datasets/test/images
# Out:
# /home/vmadmin/goqba/mk2/YOLO2
# Ultralytics YOLOv8.0.143 🚀 Python-3.7.16 torch-1.13.1 CUDA:0 (Tesla T4, 14966MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# image 1/1500 /home/vmadmin/goqba/mk2/YOLO2/datasets/test/images/11655-3a_frame_0.jpg: 384x512 85 Spermss, 12.7ms
# image 2/1500 /home/vmadmin/goqba/mk2/YOLO2/datasets/test/images/11655-3a_frame_1.jpg: 384x512 78 Spermss, 10.8ms
# image 3/1500 /home/vmadmin/goqba/mk2/YOLO2/datasets/test/images/11655-3a_frame_10.jpg: 384x512 85 Spermss, 10.7ms
# image 4/1500 /home/vmadmin/goqba/mk2/YOLO2/datasets/test/images/11655-3a_frame_11.jpg: 384x512 83 Spermss, 10.7ms
# image 5/1500 /home/vmadmin/goqba/mk2/YOLO2/datasets/test/images/11655-3a_frame_12.jpg: 384x512 77 Spermss, 10.7ms
# image 6/1500 /home/vmadmin/goqba/mk2/YOLO2/datasets/test/images/11655-3a_frame_13.jpg: 384x512 87 Spermss, 10.7ms
# image 7/1500 /home/vmadmin/goqba/mk2/YOLO2/datasets/test/images/11655-3a_frame_14.jpg: 384x512 79 Spermss, 10.7ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/detect/predict17/*.jpg')[:1]:
    display(Image(filename=image_path, width=800))
    print("\n")

# %%
# %cd {HOME}
# Out:
# /home/vmadmin/goqba/mk2/20230822/YOLO20230822

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/38264-1a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/38264-1a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/38264-1a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/38264-1a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/38264-1a.mp4 --device=2,3 hide_labels=True
# Out:
# WARNING ⚠️ '--device=2,3' does not require leading dashes '--', updating to 'device=2,3'.
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# Ultralytics YOLOv8.0.143 🚀 Python-3.7.16 torch-1.13.1 CUDA:2 (Tesla T4, 14966MiB)
#                                                        CUDA:3 (Tesla T4, 14966MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# video 1/1 (1/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/38264-1a.mp4: 384x512 22 Spermss, 13.4ms
# video 1/1 (2/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/38264-1a.mp4: 384x512 21 Spermss, 7.5ms
# video 1/1 (3/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/38264-1a.mp4: 384x512 21 Spermss, 8.1ms
# video 1/1 (4/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/38264-1a.mp4: 384x512 22 Spermss, 6.9ms
# video 1/1 (5/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/38264-1a.mp4: 384x512 22 Spermss, 6.9ms
# ...

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/38496-1a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/38496-2a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/38496-3a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/38496-4a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/38496-5a.mp4 --device=2,3 hide_labels=True
# Out:
# WARNING ⚠️ '--device=2,3' does not require leading dashes '--', updating to 'device=2,3'.
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# Traceback (most recent call last):
#   File "/home/vmadmin/anaconda3/envs/user3/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/home/vmadmin/anaconda3/envs/user3/lib/python3.7/site-packages/ultralytics/cfg/__init__.py", line 396, in entrypoint
#     model = YOLO(model, task=task)
#   File "/home/vmadmin/anaconda3/envs/user3/lib/python3.7/site-packages/ultralytics/engine/model.py", line 93, in __init__
#     self._load(model, task)
#   File "/home/vmadmin/anaconda3/envs/user3/lib/python3.7/site-packages/ultralytics/engine/model.py", line 139, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
# ...

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/42245-1a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/42245-2a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/42245-3a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/42245-4a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/42245-5a.mp4 --device=2,3 hide_labels=True
# Out:
# WARNING ⚠️ '--device=2,3' does not require leading dashes '--', updating to 'device=2,3'.
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# Ultralytics YOLOv8.0.143 🚀 Python-3.7.16 torch-1.13.1 CUDA:2 (Tesla T4, 14966MiB)
#                                                        CUDA:3 (Tesla T4, 14966MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# video 1/1 (1/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/42245-1a.mp4: 384x512 219 Spermss, 13.6ms
# video 1/1 (2/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/42245-1a.mp4: 384x512 219 Spermss, 10.8ms
# video 1/1 (3/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/42245-1a.mp4: 384x512 216 Spermss, 10.7ms
# video 1/1 (4/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/42245-1a.mp4: 384x512 213 Spermss, 10.7ms
# video 1/1 (5/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/42245-1a.mp4: 384x512 213 Spermss, 10.8ms
# ...

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/42804-1a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/42804-2a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/42804-3a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/42804-4a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/42804-5a.mp4 --device=2,3 hide_labels=True
# Out:
# WARNING ⚠️ '--device=2,3' does not require leading dashes '--', updating to 'device=2,3'.
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# Ultralytics YOLOv8.0.143 🚀 Python-3.7.16 torch-1.13.1 CUDA:2 (Tesla T4, 14966MiB)
#                                                        CUDA:3 (Tesla T4, 14966MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# video 1/1 (1/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/42804-1a.mp4: 384x512 110 Spermss, 13.2ms
# video 1/1 (2/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/42804-1a.mp4: 384x512 113 Spermss, 11.1ms
# video 1/1 (3/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/42804-1a.mp4: 384x512 108 Spermss, 10.7ms
# video 1/1 (4/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/42804-1a.mp4: 384x512 111 Spermss, 10.7ms
# video 1/1 (5/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/42804-1a.mp4: 384x512 111 Spermss, 10.7ms
# ...

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/49705-1a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/49705-2a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/49705-3a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/49705-4a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/49705-5a.mp4 --device=2,3 hide_labels=True
# Out:
# WARNING ⚠️ '--device=2,3' does not require leading dashes '--', updating to 'device=2,3'.
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# Ultralytics YOLOv8.0.143 🚀 Python-3.7.16 torch-1.13.1 CUDA:2 (Tesla T4, 14966MiB)
#                                                        CUDA:3 (Tesla T4, 14966MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# video 1/1 (1/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/49705-1a.mp4: 384x512 71 Spermss, 12.6ms
# video 1/1 (2/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/49705-1a.mp4: 384x512 73 Spermss, 11.5ms
# video 1/1 (3/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/49705-1a.mp4: 384x512 72 Spermss, 10.8ms
# video 1/1 (4/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/49705-1a.mp4: 384x512 72 Spermss, 10.7ms
# video 1/1 (5/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/49705-1a.mp4: 384x512 69 Spermss, 10.7ms
# ...

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/57824-1a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/57824-2a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/57824-3a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/57824-4a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/57824-5a.mp4 --device=2,3 hide_labels=True
# Out:
# WARNING ⚠️ '--device=2,3' does not require leading dashes '--', updating to 'device=2,3'.
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# Ultralytics YOLOv8.0.143 🚀 Python-3.7.16 torch-1.13.1 CUDA:2 (Tesla T4, 14966MiB)
#                                                        CUDA:3 (Tesla T4, 14966MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# video 1/1 (1/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/57824-1a.mp4: 384x512 130 Spermss, 13.5ms
# video 1/1 (2/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/57824-1a.mp4: 384x512 126 Spermss, 11.4ms
# video 1/1 (3/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/57824-1a.mp4: 384x512 130 Spermss, 10.7ms
# video 1/1 (4/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/57824-1a.mp4: 384x512 129 Spermss, 10.8ms
# video 1/1 (5/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/57824-1a.mp4: 384x512 128 Spermss, 10.7ms
# ...

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/29254-1a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/29254-2a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/29254-3a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/29254-4a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/29254-5a.mp4 --device=2,3 hide_labels=True
# Out:
# WARNING ⚠️ '--device=2,3' does not require leading dashes '--', updating to 'device=2,3'.
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# Ultralytics YOLOv8.0.143 🚀 Python-3.7.16 torch-1.13.1 CUDA:2 (Tesla T4, 14966MiB)
#                                                        CUDA:3 (Tesla T4, 14966MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# video 1/1 (1/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/29254-1a.mp4: 384x512 32 Spermss, 13.0ms
# video 1/1 (2/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/29254-1a.mp4: 384x512 38 Spermss, 11.2ms
# video 1/1 (3/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/29254-1a.mp4: 384x512 38 Spermss, 10.7ms
# video 1/1 (4/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/29254-1a.mp4: 384x512 39 Spermss, 10.7ms
# video 1/1 (5/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/29254-1a.mp4: 384x512 39 Spermss, 10.7ms
# ...

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/44808-1a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/44808-2a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/44808-3a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/44808-4a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/44808-5a.mp4 --device=2,3 hide_labels=True
# Out:
# WARNING ⚠️ '--device=2,3' does not require leading dashes '--', updating to 'device=2,3'.
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# Ultralytics YOLOv8.0.143 🚀 Python-3.7.16 torch-1.13.1 CUDA:2 (Tesla T4, 14966MiB)
#                                                        CUDA:3 (Tesla T4, 14966MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# video 1/1 (1/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/44808-1a.mp4: 384x512 63 Spermss, 12.7ms
# video 1/1 (2/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/44808-1a.mp4: 384x512 65 Spermss, 10.5ms
# video 1/1 (3/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/44808-1a.mp4: 384x512 64 Spermss, 10.7ms
# video 1/1 (4/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/44808-1a.mp4: 384x512 65 Spermss, 12.2ms
# video 1/1 (5/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/44808-1a.mp4: 384x512 68 Spermss, 10.8ms
# ...

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/66767-1a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/66767-2a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/66767-3a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/66767-4a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/66767-5a.mp4 --device=2,3 hide_labels=True
# Out:
# WARNING ⚠️ '--device=2,3' does not require leading dashes '--', updating to 'device=2,3'.
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# Ultralytics YOLOv8.0.143 🚀 Python-3.7.16 torch-1.13.1 CUDA:2 (Tesla T4, 14966MiB)
#                                                        CUDA:3 (Tesla T4, 14966MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# video 1/1 (1/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/66767-1a.mp4: 384x512 265 Spermss, 15.7ms
# video 1/1 (2/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/66767-1a.mp4: 384x512 258 Spermss, 8.3ms
# video 1/1 (3/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/66767-1a.mp4: 384x512 265 Spermss, 7.3ms
# video 1/1 (4/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/66767-1a.mp4: 384x512 265 Spermss, 8.8ms
# video 1/1 (5/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/66767-1a.mp4: 384x512 265 Spermss, 7.2ms
# ...

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/41377-1a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/41377-2a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/41377-3a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/41377-4a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/41377-5a.mp4 --device=2,3 hide_labels=True
# Out:
# WARNING ⚠️ '--device=2,3' does not require leading dashes '--', updating to 'device=2,3'.
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# Ultralytics YOLOv8.0.143 🚀 Python-3.7.16 torch-1.13.1 CUDA:2 (Tesla T4, 14966MiB)
#                                                        CUDA:3 (Tesla T4, 14966MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# video 1/1 (1/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/41377-1a.mp4: 384x512 55 Spermss, 13.3ms
# video 1/1 (2/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/41377-1a.mp4: 384x512 52 Spermss, 10.8ms
# video 1/1 (3/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/41377-1a.mp4: 384x512 52 Spermss, 10.7ms
# video 1/1 (4/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/41377-1a.mp4: 384x512 51 Spermss, 11.1ms
# video 1/1 (5/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/41377-1a.mp4: 384x512 55 Spermss, 10.8ms
# ...

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/64768-1a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/64768-2a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/64768-3a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/64768-4a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/64768-5a.mp4 --device=2,3 hide_labels=True
# Out:
# WARNING ⚠️ '--device=2,3' does not require leading dashes '--', updating to 'device=2,3'.
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# Ultralytics YOLOv8.0.143 🚀 Python-3.7.16 torch-1.13.1 CUDA:2 (Tesla T4, 14966MiB)
#                                                        CUDA:3 (Tesla T4, 14966MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# video 1/1 (1/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/64768-1a.mp4: 384x512 50 Spermss, 13.1ms
# video 1/1 (2/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/64768-1a.mp4: 384x512 52 Spermss, 8.5ms
# video 1/1 (3/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/64768-1a.mp4: 384x512 50 Spermss, 7.9ms
# video 1/1 (4/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/64768-1a.mp4: 384x512 51 Spermss, 8.1ms
# video 1/1 (5/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/64768-1a.mp4: 384x512 47 Spermss, 7.9ms
# ...

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/62852-1a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/62852-2a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/62852-3a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/62852-4a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/home/vmadmin/goqba/mk2/YOLO2/nipa/new/62852-5a.mp4 --device=2,3 hide_labels=True
# Out:
# WARNING ⚠️ '--device=2,3' does not require leading dashes '--', updating to 'device=2,3'.
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# Ultralytics YOLOv8.0.143 🚀 Python-3.7.16 torch-1.13.1 CUDA:2 (Tesla T4, 14966MiB)
#                                                        CUDA:3 (Tesla T4, 14966MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# video 1/1 (1/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/62852-1a.mp4: 384x512 300 Spermss, 13.9ms
# video 1/1 (2/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/62852-1a.mp4: 384x512 300 Spermss, 7.8ms
# video 1/1 (3/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/62852-1a.mp4: 384x512 300 Spermss, 7.4ms
# video 1/1 (4/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/62852-1a.mp4: 384x512 300 Spermss, 7.4ms
# video 1/1 (5/25) /home/vmadmin/goqba/mk2/YOLO2/nipa/new/62852-1a.mp4: 384x512 300 Spermss, 8.1ms
# ...

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source={HOME}/44509-1a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source={HOME}/44509-2a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source={HOME}/44509-3a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source={HOME}/44509-4a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source={HOME}/44509-5a.mp4 --device=2,3 hide_labels=True
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source={HOME}/72242-3a.mp4 --device=2,3 hide_labels=True
# Out:
# WARNING ⚠️ '--device=2,3' does not require leading dashes '--', updating to 'device=2,3'.
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# Ultralytics YOLOv8.0.143 🚀 Python-3.7.16 torch-1.13.1 CUDA:2 (Tesla T4, 14966MiB)
#                                                        CUDA:3 (Tesla T4, 14966MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# video 1/1 (1/25) /home/vmadmin/goqba/mk2/20230822/YOLO20230822/44509-1a.mp4: 384x512 103 Spermss, 13.2ms
# video 1/1 (2/25) /home/vmadmin/goqba/mk2/20230822/YOLO20230822/44509-1a.mp4: 384x512 103 Spermss, 11.4ms
# video 1/1 (3/25) /home/vmadmin/goqba/mk2/20230822/YOLO20230822/44509-1a.mp4: 384x512 100 Spermss, 10.7ms
# video 1/1 (4/25) /home/vmadmin/goqba/mk2/20230822/YOLO20230822/44509-1a.mp4: 384x512 104 Spermss, 10.7ms
# video 1/1 (5/25) /home/vmadmin/goqba/mk2/20230822/YOLO20230822/44509-1a.mp4: 384x512 102 Spermss, 10.9ms
# ...
