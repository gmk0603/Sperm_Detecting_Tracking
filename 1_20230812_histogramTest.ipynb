# %% [markdown]
# # 최종 코드(마지막에 있음)

# %%
import os
os.getcwd()
# Out:
# 'c:\\jupyter\\sperm'

# %%
# 파일 정렬 라이브러리
# !pip install natsort

# %% [markdown]
# # 프레임으로 분할 후 폴더에 저장

# %%
import os
import cv2
import natsort

def split_videos_in_folder(path):
    # 바운딩 영상을 가져올 폴더
    input_folder = path

    # 프레임을 저장할 폴더
    output_folder = "C:/jupyter/sperm/frame/"

    # 입력 폴더의 모든 파일을 가져옵니다. 지 마음대로 가져옴
    # files = os.listdir(input_folder)

    # 파일 정렬
    files = natsort.natsorted(os.listdir(input_folder))

    # 프레임을 저장할 폴더를 생성합니다.
    os.makedirs(output_folder, exist_ok=True)

    for file in files:
        frame_count = 0
                
        # 파일의 확장자를 가져옵니다.
        _, ext = os.path.splitext(file)

        # 파일이 영상 파일인지 확인합니다. (확장자가 .mp4, .avi 등)
        if ext.lower() in [".mp4", ".avi"]:
            # 영상 파일을 엽니다.
            video_path = os.path.join(input_folder, file)
            cap = cv2.VideoCapture(video_path)

            # 비디오 열기를 실패하면 다음 파일로 넘어갑니다.
            if not cap.isOpened():
                print(f"{file} 비디오 열기 실패")
                continue

            # 동영상 파일명에서 확장자 제거하여 저장할 이미지 파일명으로 사용합니다.
            video_name = os.path.splitext(file)[0]

            while True:
                # 프레임을 읽습니다.
                ret, frame = cap.read()
                if not ret:
                    break

                # 프레임을 이미지 파일로 저장합니다.
                frame_path = os.path.join(output_folder, f"{video_name}_{frame_count}.jpg")
                cv2.imwrite(frame_path, frame)

                frame_count += 1

            cap.release()
            print(f"{file} 프레임 분할 완료")

# 기본 경로
path = "C:/jupyter/sperm/video/little"
path2 = "C:/jupyter/sperm/video/many"
#path = "/home/vmadmin/goqba/mk2/extractTest"

def main():
    split_videos_in_folder(path2)
    
if __name__ == "__main__":
    main()
    cv2.destroyAllWindows()
# Out:
# 13260-1a.mp4 프레임 분할 완료
# 13260-2a.mp4 프레임 분할 완료
# 13260-3a.mp4 프레임 분할 완료
# 13260-4a.mp4 프레임 분할 완료
# 13260-5a.mp4 프레임 분할 완료
# 21993-1a.mp4 프레임 분할 완료
# 21993-2a.mp4 프레임 분할 완료
# 21993-3a.mp4 프레임 분할 완료
# 21993-4a.mp4 프레임 분할 완료
# 21993-5a.mp4 프레임 분할 완료
# 54088-1a.mp4 프레임 분할 완료
# 54088-2a.mp4 프레임 분할 완료
# 54088-3a.mp4 프레임 분할 완료
# 54088-4a.mp4 프레임 분할 완료
# 54088-5a.mp4 프레임 분할 완료
# 56830-1a.mp4 프레임 분할 완료
# 56830-2a.mp4 프레임 분할 완료
# 56830-3a.mp4 프레임 분할 완료
# 56830-4a.mp4 프레임 분할 완료
# 56830-5a.mp4 프레임 분할 완료
# 58437-1a.mp4 프레임 분할 완료
# 58437-2a.mp4 프레임 분할 완료
# 58437-3a.mp4 프레임 분할 완료
# 58437-4a.mp4 프레임 분할 완료
# 58437-5a.mp4 프레임 분할 완료
# 58482-1a.mp4 프레임 분할 완료
# 58482-2a.mp4 프레임 분할 완료
# 58482-3a.mp4 프레임 분할 완료
# 58482-4a.mp4 프레임 분할 완료
# 58482-5a.mp4 프레임 분할 완료
# 59201-1a.mp4 프레임 분할 완료
# 59201-2a.mp4 프레임 분할 완료
# 59201-3a.mp4 프레임 분할 완료
# 59201-4a.mp4 프레임 분할 완료
# 59201-5a.mp4 프레임 분할 완료
# 60998-1a.mp4 프레임 분할 완료
# 60998-2a.mp4 프레임 분할 완료
# 60998-3a.mp4 프레임 분할 완료
# 60998-4a.mp4 프레임 분할 완료
# 60998-5a.mp4 프레임 분할 완료
# 61874-1a.mp4 프레임 분할 완료
# 61874-2a.mp4 프레임 분할 완료
# 61874-3a.mp4 프레임 분할 완료
# 61874-4a.mp4 프레임 분할 완료
# 61874-5a.mp4 프레임 분할 완료
# 63332-1a.mp4 프레임 분할 완료
# 63332-2a.mp4 프레임 분할 완료
# 63332-3a.mp4 프레임 분할 완료
# 63332-4a.mp4 프레임 분할 완료
# 63332-5a.mp4 프레임 분할 완료
# 63388-1a.mp4 프레임 분할 완료
# 63388-2a.mp4 프레임 분할 완료
# 63388-3a.mp4 프레임 분할 완료
# 63388-4a.mp4 프레임 분할 완료
# 63388-5a.mp4 프레임 분할 완료
# 63862-1a.mp4 프레임 분할 완료
# 63862-2a.mp4 프레임 분할 완료
# 63862-3a.mp4 프레임 분할 완료
# 63862-4a.mp4 프레임 분할 완료
# 63862-5a.mp4 프레임 분할 완료
# 64273-1a.mp4 프레임 분할 완료
# 64273-2a.mp4 프레임 분할 완료
# 64273-3a.mp4 프레임 분할 완료
# 64273-4a.mp4 프레임 분할 완료
# 64273-5a.mp4 프레임 분할 완료
# 65070-1a.mp4 프레임 분할 완료
# 65070-2a.mp4 프레임 분할 완료
# 65070-3a.mp4 프레임 분할 완료
# 65070-4a.mp4 프레임 분할 완료
# 65070-5a.mp4 프레임 분할 완료
# 65405-1a.mp4 프레임 분할 완료
# 65405-2a.mp4 프레임 분할 완료
# 65405-3a.mp4 프레임 분할 완료
# 65405-4a.mp4 프레임 분할 완료
# 65405-5a.mp4 프레임 분할 완료
# 66672-1a.mp4 프레임 분할 완료
# 66672-2a.mp4 프레임 분할 완료
# 66672-3a.mp4 프레임 분할 완료
# 66672-4a.mp4 프레임 분할 완료
# 66672-5a.mp4 프레임 분할 완료
# 90407-1a.mp4 프레임 분할 완료
# 90407-2a.mp4 프레임 분할 완료
# 90407-3a.mp4 프레임 분할 완료
# 90407-4a.mp4 프레임 분할 완료
# 90407-5a.mp4 프레임 분할 완료
# 90490-1a.mp4 프레임 분할 완료
# 90490-2a.mp4 프레임 분할 완료
# 90490-3a.mp4 프레임 분할 완료
# 90490-4a.mp4 프레임 분할 완료
# 90490-5a.mp4 프레임 분할 완료

# %% [markdown]
# # 이미지 하나에 대한 히스토그램 출력(그래프로)
# ### 프레임으로 분할된 이미지 중 하나를 선택해 테스트 해봄

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import random

# 이미지 폴더 경로
image_folder = 'C:/jupyter/sperm/frame/'

# 이미지 파일 목록 생성
image_files = [f for f in os.listdir(image_folder) if f.endswith('.jpg')]

# 랜덤하게 이미지 선택
selected_image_filename = random.choice(image_files)
selected_image_path = os.path.join(image_folder, selected_image_filename)

# 이미지 불러오기
image = cv2.imread(selected_image_path, cv2.IMREAD_GRAYSCALE)

# 이미지가 정상적으로 불러와졌는지 확인
if image is None:
    print("이미지를 불러올 수 없습니다.")
    exit()

# 히스토그램 계산
hist = cv2.calcHist([image], [0], None, [256], [0, 256])

# 선택된 이미지 출력
plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')
plt.title("Selected Image")
plt.axis('off')

# 히스토그램 그래프 출력
plt.subplot(1, 2, 2)
plt.plot(hist)
plt.title("Image Histogram")
plt.xlabel("Pixel Value")
plt.ylabel("Frequency")

# 창 띄우기
plt.show()

# %% [markdown]
# # 이미지 하나에 대한 히스토그램 출력(막대 그래프로)
# ### 프레임으로 분할된 이미지 중 하나를 선택해 테스트 해봄

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import random

# 이미지 폴더 경로
image_folder = 'C:/jupyter/sperm/frame/'

# 이미지 파일 목록 생성
image_files = [f for f in os.listdir(image_folder) if f.endswith('.jpg')]

# 랜덤하게 이미지 선택
selected_image_filename = random.choice(image_files)
selected_image_path = os.path.join(image_folder, selected_image_filename)

# 이미지 불러오기
image = cv2.imread(selected_image_path, cv2.IMREAD_GRAYSCALE)

# 이미지가 정상적으로 불러와졌는지 확인
if image is None:
    print("이미지를 불러올 수 없습니다.")
    exit()

# 히스토그램 계산
hist = cv2.calcHist([image], [0], None, [256], [0, 256])

# 선택된 이미지 출력
plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')
plt.title("Selected Image")
plt.axis('off')

# 막대 그래프로 히스토그램 표현
plt.subplot(1, 2, 2)
plt.bar(range(256), hist[:,0], width=1)
plt.title("Image Histogram")
plt.xlabel("Pixel Value")
plt.ylabel("Frequency")

# 창 띄우기
plt.show()

# %% [markdown]
# # 세로 출력

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import random

# 이미지 폴더 경로
image_folder = 'C:/jupyter/sperm/frame/'

# 이미지 파일 목록 생성
image_files = [f for f in os.listdir(image_folder) if f.endswith('.jpg')]

# 랜덤하게 이미지 선택
selected_image_filename = random.choice(image_files)
selected_image_path = os.path.join(image_folder, selected_image_filename)

# 이미지 불러오기
image = cv2.imread(selected_image_path, cv2.IMREAD_GRAYSCALE)

# 이미지가 정상적으로 불러와졌는지 확인
if image is None:
    print("이미지를 불러올 수 없습니다.")
    exit()

# 파일명에서 확장자 제거
file_name_without_extension = os.path.splitext(selected_image_filename)[0]

# 히스토그램 계산
hist = cv2.calcHist([image], [0], None, [256], [0, 256])

# 이미지와 파일명 출력
plt.subplot(2, 1, 1)
plt.imshow(image, cmap='gray')
plt.title(file_name_without_extension)  # 파일명을 이미지 제목으로 설정
plt.axis('off')

# 막대 그래프로 히스토그램 표현
plt.subplot(2, 1, 2)
plt.bar(range(256), hist[:,0], width=1)
plt.title(file_name_without_extension + " Image Histogram")
plt.xlabel("Pixel Value")
plt.ylabel("Frequency")

# 창 띄우기
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 빈도수가 가장 많은 픽셀 값, 해당 픽셀 값의 빈도수

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import random

# 이미지 폴더 경로
image_folder = 'C:/jupyter/sperm/frame/'

# 이미지 파일 목록 생성
image_files = [f for f in os.listdir(image_folder) if f.endswith('.jpg')]

# 랜덤하게 이미지 선택
selected_image_filename = random.choice(image_files)
selected_image_path = os.path.join(image_folder, selected_image_filename)

# 이미지 불러오기
image = cv2.imread(selected_image_path, cv2.IMREAD_GRAYSCALE)

# 이미지가 정상적으로 불러와졌는지 확인
if image is None:
    print("이미지를 불러올 수 없습니다.")
    exit()

# 파일명에서 확장자 제거
file_name_without_extension = os.path.splitext(selected_image_filename)[0]

# 히스토그램 계산
hist = cv2.calcHist([image], [0], None, [256], [0, 256])

# 이미지와 파일명 출력
plt.subplot(2, 1, 1)
plt.imshow(image, cmap='gray')
plt.title(file_name_without_extension)  # 파일명을 이미지 제목으로 설정
plt.axis('off')

# 막대 그래프로 히스토그램 표현
plt.subplot(2, 1, 2)
plt.bar(range(256), hist[:,0], width=1)
plt.title(file_name_without_extension + " Image Histogram")
plt.xlabel("Pixel Value")
plt.ylabel("Frequency")

# 차트에서 빈도수가 가장 큰 값 찾기
max_frequency_value = np.argmax(hist)
max_frequency = hist[max_frequency_value]

print(f"빈도수가 가장 많은 픽셀 값: {max_frequency_value}, 빈도수: {max_frequency[0]}")

# 창 띄우기
plt.tight_layout()
plt.show()
# Out:
# 빈도수가 가장 큰 픽셀 값: 30, 빈도수: 74313.0

# %% [markdown]
# ### 빈도수가 가장 많은 픽셀 값, 해당 픽셀 값의 빈도수, 이미지 픽셀 평균

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import random

# 이미지 폴더 경로
image_folder = 'C:/jupyter/sperm/frame/'

# 이미지 파일 목록 생성
image_files = [f for f in os.listdir(image_folder) if f.endswith('.jpg')]

# 랜덤하게 이미지 선택
selected_image_filename = random.choice(image_files)
selected_image_path = os.path.join(image_folder, selected_image_filename)

# 이미지 불러오기
image = cv2.imread(selected_image_path, cv2.IMREAD_GRAYSCALE)

# 이미지가 정상적으로 불러와졌는지 확인
if image is None:
    print("이미지를 불러올 수 없습니다.")
    exit()

# 파일명에서 확장자 제거
file_name_without_extension = os.path.splitext(selected_image_filename)[0]

# 히스토그램 계산
hist = cv2.calcHist([image], [0], None, [256], [0, 256])

# 이미지와 파일명 출력
plt.subplot(2, 1, 1)
plt.imshow(image, cmap='gray')
plt.title(file_name_without_extension)  # 파일명을 이미지 제목으로 설정
plt.axis('off')

# 막대 그래프로 히스토그램 표현
plt.subplot(2, 1, 2)
plt.bar(range(256), hist[:,0], width=1)
plt.title(file_name_without_extension + " Image Histogram")
plt.xlabel("Pixel Value")
plt.ylabel("Frequency")

# 빈도수가 가장 큰 값 찾기
max_frequency_value = np.argmax(hist)
max_frequency = hist[max_frequency_value]

# 이미지 픽셀 값의 평균 계산
average_pixel_value = np.mean(image)

print(f"빈도수가 가장 큰 픽셀 값: {max_frequency_value}, 빈도수: {max_frequency[0]}")
print(f"이미지 픽셀 값의 평균: {average_pixel_value:.2f}")

# 창 띄우기
plt.tight_layout()
plt.show()
# Out:
# 빈도수가 가장 큰 픽셀 값: 31, 빈도수: 61864.0
# 이미지 픽셀 값의 평균: 33.31

# %% [markdown]
# # 히스토그램 저장하기(히스토그램만 이미지로 저장됨)

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import random

# 이미지 폴더 경로
image_folder = 'C:/jupyter/sperm/frame/'

# 이미지 파일 목록 생성
image_files = [f for f in os.listdir(image_folder) if f.endswith('.jpg')]

# 랜덤하게 이미지 선택
selected_image_filename = random.choice(image_files)
selected_image_path = os.path.join(image_folder, selected_image_filename)

# 이미지 불러오기
image = cv2.imread(selected_image_path, cv2.IMREAD_GRAYSCALE)

# 이미지가 정상적으로 불러와졌는지 확인
if image is None:
    print("이미지를 불러올 수 없습니다.")
    exit()

# 파일명에서 확장자 제거
file_name_without_extension = os.path.splitext(selected_image_filename)[0]

# 히스토그램 계산
hist = cv2.calcHist([image], [0], None, [256], [0, 256])

# 막대 그래프로 히스토그램 표현
plt.bar(range(256), hist[:,0], width=1)
plt.title(file_name_without_extension + " Image Histogram")
plt.xlabel("Pixel Value")
plt.ylabel("Frequency")

# 빈도수가 가장 큰 값 찾기
max_frequency_value = np.argmax(hist)
max_frequency = hist[max_frequency_value]

# 이미지 픽셀 값의 평균 계산
average_pixel_value = np.mean(image)

print(f"빈도수가 가장 큰 픽셀 값: {max_frequency_value}, 빈도수: {max_frequency[0]}")
print(f"이미지 픽셀 값의 평균: {average_pixel_value:.2f}")

# 지정한 경로가 존재하지 않을 경우 경로 생성
output_directory = 'C:/jupyter/sperm/histograms/'
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# 히스토그램 이미지 저장
output_image_path = os.path.join(output_directory, f"{file_name_without_extension}_histogram.png")
plt.savefig(output_image_path)

# 창 띄우기
plt.tight_layout()
plt.show()
# Out:
# 빈도수가 가장 큰 픽셀 값: 31, 빈도수: 115889.0
# 이미지 픽셀 값의 평균: 31.24

# %% [markdown]
# # 파일명, 빈도수가 가장 많은 픽셀 값, 빈도수, 이미지 픽셀 값의 평균을 CSV로 저장(이미지 하나 기준)

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import random
import csv

# 이미지 폴더 경로
image_folder = 'C:/jupyternotebook/hist/frame/21993-1a.jpg'

# 이미지 파일 목록 생성
#image_files = [f for f in os.listdir(image_folder) if f.endswith('.jpg')]

# 랜덤하게 이미지 선택
selected_image_filename = image_folder
#selected_image_path = os.path.join(image_folder, selected_image_filename)

# 이미지 불러오기
image = cv2.imread(image_folder, cv2.IMREAD_GRAYSCALE)

# 이미지가 정상적으로 불러와졌는지 확인
if image is None:
    print("이미지를 불러올 수 없습니다.")
    exit()

# 파일명에서 확장자 제거
file_name_without_extension = os.path.splitext(selected_image_filename)[0]

# 히스토그램 계산
hist = cv2.calcHist([image], [0], None, [256], [0, 256])

# 이미지 출력
plt.imshow(image, cmap='gray')
plt.title(file_name_without_extension)  # 파일명을 이미지 제목으로 설정
plt.axis('off')
plt.show()

# 막대 그래프로 히스토그램 표현
plt.bar(range(256), hist[:,0], width=1)
plt.title(file_name_without_extension + " Image Histogram")
plt.xlabel("Pixel Value")
plt.ylabel("Frequency")
plt.show()

# 빈도수가 가장 큰 값 찾기
max_frequency_value = np.argmax(hist)
max_frequency = hist[max_frequency_value]

# 이미지 픽셀 값의 평균 계산
average_pixel_value = np.mean(image)

# 히스토그램의 x 축 값 중에서 가장 큰 값을 찾아 출력
max_pixel_value = np.argmax(hist)


print(f"빈도수가 가장 많은 픽셀 값: {max_frequency_value}, 빈도수: {max_frequency[0]}")
print(f"이미지 픽셀 값의 평균: {average_pixel_value:.2f}")
print(f"가장 큰 픽셀 값: {max_pixel_value}")

# 히스토그램의 모든 x 값 출력
for pixel_value, frequency in enumerate(hist):
    print(f"Pixel Value: {pixel_value}, Frequency: {int(frequency[0])}")
    
# 지정한 경로가 존재하지 않을 경우 경로 생성
output_directory = 'C:/jupyter/sperm/histograms/'
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# 히스토그램 이미지 저장
output_image_path = os.path.join(output_directory, f"{file_name_without_extension}_histogram.png")
plt.bar(range(256), hist[:,0], width=1)
plt.title(file_name_without_extension + " Image Histogram")
plt.xlabel("Pixel Value")
plt.ylabel("Frequency")
plt.savefig(output_image_path)
plt.close()

# CSV 파일에 저장
csv_output_path = os.path.join(output_directory, f"{file_name_without_extension}.csv")
csv_header = ['파일명', '가장 많은 픽셀 값', '빈도 수', '픽셀 값 평균']
csv_data = [file_name_without_extension, max_frequency_value, max_frequency[0], average_pixel_value]

# 파일이 존재하지 않으면 헤더와 함께 파일을 생성하고, 이미 존재하면 데이터를 추가합니다.
if not os.path.exists(csv_output_path):
    with open(csv_output_path, mode='w', newline='') as csv_file:
        writer = csv.writer(csv_file)
        writer.writerow(csv_header)
        writer.writerow(csv_data)
else:
    with open(csv_output_path, mode='a', newline='') as csv_file:
        writer = csv.writer(csv_file)
        writer.writerow(csv_data)
# Out:
# 빈도수가 가장 많은 픽셀 값: 27, 빈도수: 74268.0
# 이미지 픽셀 값의 평균: 29.27
# 가장 큰 픽셀 값: 27
# Pixel Value: 0, Frequency: 0
# Pixel Value: 1, Frequency: 0
# Pixel Value: 2, Frequency: 0
# Pixel Value: 3, Frequency: 0
# Pixel Value: 4, Frequency: 1
# Pixel Value: 5, Frequency: 1
# Pixel Value: 6, Frequency: 0
# Pixel Value: 7, Frequency: 2
# Pixel Value: 8, Frequency: 6
# Pixel Value: 9, Frequency: 15
# Pixel Value: 10, Frequency: 13
# Pixel Value: 11, Frequency: 31
# Pixel Value: 12, Frequency: 45
# Pixel Value: 13, Frequency: 75
# Pixel Value: 14, Frequency: 63
# Pixel Value: 15, Frequency: 135
# Pixel Value: 16, Frequency: 214
# Pixel Value: 17, Frequency: 253
# Pixel Value: 18, Frequency: 352
# Pixel Value: 19, Frequency: 498
# Pixel Value: 20, Frequency: 747
# Pixel Value: 21, Frequency: 674
# Pixel Value: 22, Frequency: 1405
# Pixel Value: 23, Frequency: 2449
# Pixel Value: 24, Frequency: 5362
# Pixel Value: 25, Frequency: 11146
# Pixel Value: 26, Frequency: 41540
# Pixel Value: 27, Frequency: 74268
# Pixel Value: 28, Frequency: 8142
# Pixel Value: 29, Frequency: 60776
# Pixel Value: 30, Frequency: 37392
# Pixel Value: 31, Frequency: 23899
# Pixel Value: 32, Frequency: 12189
# Pixel Value: 33, Frequency: 6481
# Pixel Value: 34, Frequency: 3885
# Pixel Value: 35, Frequency: 1898
# Pixel Value: 36, Frequency: 2183
# Pixel Value: 37, Frequency: 1682
# Pixel Value: 38, Frequency: 1250
# Pixel Value: 39, Frequency: 895
# Pixel Value: 40, Frequency: 615
# Pixel Value: 41, Frequency: 447
# Pixel Value: 42, Frequency: 293
# Pixel Value: 43, Frequency: 312
# Pixel Value: 44, Frequency: 288
# Pixel Value: 45, Frequency: 249
# Pixel Value: 46, Frequency: 247
# Pixel Value: 47, Frequency: 185
# Pixel Value: 48, Frequency: 156
# Pixel Value: 49, Frequency: 115
# Pixel Value: 50, Frequency: 158
# Pixel Value: 51, Frequency: 145
# Pixel Value: 52, Frequency: 143
# Pixel Value: 53, Frequency: 126
# Pixel Value: 54, Frequency: 120
# Pixel Value: 55, Frequency: 99
# Pixel Value: 56, Frequency: 84
# Pixel Value: 57, Frequency: 100
# Pixel Value: 58, Frequency: 101
# Pixel Value: 59, Frequency: 104
# Pixel Value: 60, Frequency: 110
# Pixel Value: 61, Frequency: 107
# Pixel Value: 62, Frequency: 89
# Pixel Value: 63, Frequency: 56
# Pixel Value: 64, Frequency: 71
# Pixel Value: 65, Frequency: 86
# Pixel Value: 66, Frequency: 84
# Pixel Value: 67, Frequency: 100
# Pixel Value: 68, Frequency: 82
# Pixel Value: 69, Frequency: 66
# Pixel Value: 70, Frequency: 45
# Pixel Value: 71, Frequency: 66
# Pixel Value: 72, Frequency: 53
# Pixel Value: 73, Frequency: 64
# Pixel Value: 74, Frequency: 51
# Pixel Value: 75, Frequency: 57
# Pixel Value: 76, Frequency: 65
# Pixel Value: 77, Frequency: 39
# Pixel Value: 78, Frequency: 49
# Pixel Value: 79, Frequency: 56
# Pixel Value: 80, Frequency: 63
# Pixel Value: 81, Frequency: 57
# Pixel Value: 82, Frequency: 54
# Pixel Value: 83, Frequency: 33
# Pixel Value: 84, Frequency: 36
# Pixel Value: 85, Frequency: 52
# Pixel Value: 86, Frequency: 45
# Pixel Value: 87, Frequency: 57
# Pixel Value: 88, Frequency: 39
# Pixel Value: 89, Frequency: 41
# Pixel Value: 90, Frequency: 51
# Pixel Value: 91, Frequency: 47
# Pixel Value: 92, Frequency: 34
# Pixel Value: 93, Frequency: 39
# Pixel Value: 94, Frequency: 40
# Pixel Value: 95, Frequency: 38
# Pixel Value: 96, Frequency: 37
# Pixel Value: 97, Frequency: 37
# Pixel Value: 98, Frequency: 27
# Pixel Value: 99, Frequency: 21
# Pixel Value: 100, Frequency: 26
# Pixel Value: 101, Frequency: 21
# Pixel Value: 102, Frequency: 28
# Pixel Value: 103, Frequency: 31
# Pixel Value: 104, Frequency: 22
# Pixel Value: 105, Frequency: 28
# Pixel Value: 106, Frequency: 17
# Pixel Value: 107, Frequency: 21
# Pixel Value: 108, Frequency: 34
# Pixel Value: 109, Frequency: 21
# Pixel Value: 110, Frequency: 24
# Pixel Value: 111, Frequency: 43
# Pixel Value: 112, Frequency: 20
# Pixel Value: 113, Frequency: 16
# Pixel Value: 114, Frequency: 22
# Pixel Value: 115, Frequency: 14
# Pixel Value: 116, Frequency: 19
# Pixel Value: 117, Frequency: 16
# Pixel Value: 118, Frequency: 19
# Pixel Value: 119, Frequency: 16
# Pixel Value: 120, Frequency: 8
# Pixel Value: 121, Frequency: 23
# Pixel Value: 122, Frequency: 18
# Pixel Value: 123, Frequency: 12
# Pixel Value: 124, Frequency: 26
# Pixel Value: 125, Frequency: 14
# Pixel Value: 126, Frequency: 6
# Pixel Value: 127, Frequency: 9
# Pixel Value: 128, Frequency: 8
# Pixel Value: 129, Frequency: 11
# Pixel Value: 130, Frequency: 8
# Pixel Value: 131, Frequency: 10
# Pixel Value: 132, Frequency: 15
# Pixel Value: 133, Frequency: 6
# Pixel Value: 134, Frequency: 7
# Pixel Value: 135, Frequency: 8
# Pixel Value: 136, Frequency: 7
# Pixel Value: 137, Frequency: 9
# Pixel Value: 138, Frequency: 5
# Pixel Value: 139, Frequency: 10
# Pixel Value: 140, Frequency: 10
# Pixel Value: 141, Frequency: 6
# Pixel Value: 142, Frequency: 8
# Pixel Value: 143, Frequency: 10
# Pixel Value: 144, Frequency: 3
# Pixel Value: 145, Frequency: 10
# Pixel Value: 146, Frequency: 5
# Pixel Value: 147, Frequency: 3
# Pixel Value: 148, Frequency: 5
# Pixel Value: 149, Frequency: 5
# Pixel Value: 150, Frequency: 8
# Pixel Value: 151, Frequency: 6
# Pixel Value: 152, Frequency: 7
# Pixel Value: 153, Frequency: 5
# Pixel Value: 154, Frequency: 5
# Pixel Value: 155, Frequency: 2
# Pixel Value: 156, Frequency: 1
# Pixel Value: 157, Frequency: 1
# Pixel Value: 158, Frequency: 4
# Pixel Value: 159, Frequency: 8
# Pixel Value: 160, Frequency: 1
# Pixel Value: 161, Frequency: 4
# Pixel Value: 162, Frequency: 5
# Pixel Value: 163, Frequency: 2
# Pixel Value: 164, Frequency: 8
# Pixel Value: 165, Frequency: 1
# Pixel Value: 166, Frequency: 1
# Pixel Value: 167, Frequency: 2
# Pixel Value: 168, Frequency: 6
# Pixel Value: 169, Frequency: 4
# Pixel Value: 170, Frequency: 1
# Pixel Value: 171, Frequency: 2
# Pixel Value: 172, Frequency: 3
# Pixel Value: 173, Frequency: 4
# Pixel Value: 174, Frequency: 0
# Pixel Value: 175, Frequency: 7
# Pixel Value: 176, Frequency: 3
# Pixel Value: 177, Frequency: 1
# Pixel Value: 178, Frequency: 0
# Pixel Value: 179, Frequency: 0
# Pixel Value: 180, Frequency: 0
# Pixel Value: 181, Frequency: 4
# Pixel Value: 182, Frequency: 0
# Pixel Value: 183, Frequency: 4
# Pixel Value: 184, Frequency: 2
# Pixel Value: 185, Frequency: 1
# Pixel Value: 186, Frequency: 6
# Pixel Value: 187, Frequency: 2
# Pixel Value: 188, Frequency: 5
# Pixel Value: 189, Frequency: 0
# Pixel Value: 190, Frequency: 1
# Pixel Value: 191, Frequency: 0
# Pixel Value: 192, Frequency: 1
# Pixel Value: 193, Frequency: 1
# Pixel Value: 194, Frequency: 2
# Pixel Value: 195, Frequency: 2
# Pixel Value: 196, Frequency: 2
# Pixel Value: 197, Frequency: 1
# Pixel Value: 198, Frequency: 1
# Pixel Value: 199, Frequency: 0
# Pixel Value: 200, Frequency: 0
# Pixel Value: 201, Frequency: 0
# Pixel Value: 202, Frequency: 1
# Pixel Value: 203, Frequency: 0
# Pixel Value: 204, Frequency: 0
# Pixel Value: 205, Frequency: 0
# Pixel Value: 206, Frequency: 2
# Pixel Value: 207, Frequency: 1
# Pixel Value: 208, Frequency: 0
# Pixel Value: 209, Frequency: 0
# Pixel Value: 210, Frequency: 0
# Pixel Value: 211, Frequency: 0
# Pixel Value: 212, Frequency: 1
# Pixel Value: 213, Frequency: 1
# Pixel Value: 214, Frequency: 2
# Pixel Value: 215, Frequency: 0
# Pixel Value: 216, Frequency: 1
# Pixel Value: 217, Frequency: 0
# Pixel Value: 218, Frequency: 0
# Pixel Value: 219, Frequency: 1
# Pixel Value: 220, Frequency: 0
# Pixel Value: 221, Frequency: 0
# Pixel Value: 222, Frequency: 0
# Pixel Value: 223, Frequency: 0
# Pixel Value: 224, Frequency: 0
# Pixel Value: 225, Frequency: 0
# Pixel Value: 226, Frequency: 2
# Pixel Value: 227, Frequency: 0
# Pixel Value: 228, Frequency: 0
# Pixel Value: 229, Frequency: 0
# Pixel Value: 230, Frequency: 0
# Pixel Value: 231, Frequency: 2
# Pixel Value: 232, Frequency: 0
# Pixel Value: 233, Frequency: 0
# Pixel Value: 234, Frequency: 1
# Pixel Value: 235, Frequency: 0
# Pixel Value: 236, Frequency: 0
# Pixel Value: 237, Frequency: 1
# Pixel Value: 238, Frequency: 0
# Pixel Value: 239, Frequency: 0
# Pixel Value: 240, Frequency: 1
# Pixel Value: 241, Frequency: 0
# Pixel Value: 242, Frequency: 0
# Pixel Value: 243, Frequency: 0
# Pixel Value: 244, Frequency: 2
# Pixel Value: 245, Frequency: 0
# Pixel Value: 246, Frequency: 0
# Pixel Value: 247, Frequency: 0
# Pixel Value: 248, Frequency: 0
# Pixel Value: 249, Frequency: 0
# Pixel Value: 250, Frequency: 0
# Pixel Value: 251, Frequency: 1
# Pixel Value: 252, Frequency: 0
# Pixel Value: 253, Frequency: 0
# Pixel Value: 254, Frequency: 0
# Pixel Value: 255, Frequency: 2

# %% [markdown]
# # 파일 내 전체 이미지 적용(최종)

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import random
import csv
from natsort import natsorted

# 이미지 폴더 경로
image_folder = 'C:/jupyter/sperm/frame/'

# 이미지 파일 목록 생성 (자연 정렬)
image_files = natsorted([f for f in os.listdir(image_folder) if f.endswith('.jpg')])

# 지정한 경로가 존재하지 않을 경우 경로 생성
output_directory = 'C:/jupyter/sperm/histograms/'
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# CSV 파일 생성 및 헤더 작성
csv_output_path = os.path.join(output_directory, 'data.csv')
csv_header = ['파일명', '가장 많은 픽셀 값', '빈도 수', '픽셀 값 평균']

with open(csv_output_path, mode='w', newline='') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(csv_header)

# 각 이미지에 대한 작업 반복
for selected_image_filename in image_files:
    selected_image_path = os.path.join(image_folder, selected_image_filename)

    # 이미지 불러오기
    image = cv2.imread(selected_image_path, cv2.IMREAD_GRAYSCALE)

    # 이미지가 정상적으로 불러와졌는지 확인
    if image is None:
        print(f"{selected_image_filename} 이미지를 불러올 수 없습니다.")
        continue

    # 파일명에서 확장자 제거
    # file_name_without_extension = os.path.splitext(selected_image_filename)[0]

    # 히스토그램 계산
    hist = cv2.calcHist([image], [0], None, [256], [0, 256])

    # 빈도수가 가장 큰 값 찾기
    max_frequency_value = np.argmax(hist)
    max_frequency = hist[max_frequency_value]

    # 이미지 픽셀 값의 평균 계산
    average_pixel_value = np.mean(image)

    # 히스토그램 이미지 저장
    output_image_path = os.path.join(output_directory, f"{white}_histogram.png")
    plt.bar(range(256), hist[:,0], width=1)
    plt.title(file_name_without_extension + " Image Histogram")
    plt.xlabel("Pixel Value")
    plt.ylabel("Frequency")
    plt.savefig(output_image_path)
    plt.close()

    # CSV 파일에 데이터 추가
    csv_data = [file_name_without_extension, max_frequency_value, max_frequency[0], average_pixel_value]

    with open(csv_output_path, mode='a', newline='') as csv_file:
        writer = csv.writer(csv_file)
        writer.writerow(csv_data)

print("작업이 완료되었습니다.")
# Out:
# 작업이 완료되었습니다.
